# %% [markdown]
# <a href="https://colab.research.google.com/github/armandoordonez/eda_couse/blob/main/MICE_imputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Based on: https://www.machinelearningplus.com/machine-learning/mice-imputation/#google_vignette
# need to enable iterative imputer explicitly since its still experimental

# For understanding imputation please read: https://scikit-learn.org/stable/modules/impute.html

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
import pandas as pd
file_path = "https://raw.githubusercontent.com/armandoordonez/eda_couse/main/data/Churn_Modelling_m.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave        619.0    France  Female  42.0
# 1          2    15647311      Hill        608.0     Spain  Female  41.0
# 2          3    15619304      Onio        502.0    France     NaN   NaN
# 3          4    15701354      Boni        699.0    France     NaN  39.0
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2        NaN              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Define imputer
imputer = IterativeImputer(random_state=100, max_iter=10)

# %%
# Use Numeric Features
df_train = df.loc[:, ["Balance", "Age", "Exited"]]
df_train.head()
# Out:
#      Balance   Age  Exited
# 0       0.00  42.0       1
# 1   83807.86  41.0       0
# 2  159660.80   NaN       1
# 3       0.00  39.0       0
# 4        NaN  43.0       0

# %%
# fit on the dataset
imputer.fit(df_train)
# Out:
# IterativeImputer(random_state=100)

# %%
df_imputed = imputer.transform(df_train)
df_imputed[:10]
# Out:
# array([[0.00000000e+00, 4.20000000e+01, 1.00000000e+00],
#        [8.38078600e+04, 4.10000000e+01, 0.00000000e+00],
#        [1.59660800e+05, 4.47681408e+01, 1.00000000e+00],
#        [0.00000000e+00, 3.90000000e+01, 0.00000000e+00],
#        [7.25930035e+04, 4.30000000e+01, 0.00000000e+00],
#        [1.13755780e+05, 4.40000000e+01, 1.00000000e+00],
#        [0.00000000e+00, 5.00000000e+01, 0.00000000e+00],
#        [1.15046740e+05, 2.90000000e+01, 1.00000000e+00],
#        [1.42051070e+05, 4.40000000e+01, 0.00000000e+00],
#        [1.34603880e+05, 2.70000000e+01, 0.00000000e+00]])

# %%
# Replace with imputed values
df.loc[:, ["Balance", "Age", "Exited"]] = df_imputed
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender        Age  \
# 0          1    15634602  Hargrave        619.0    France  Female  42.000000
# 1          2    15647311      Hill        608.0     Spain  Female  41.000000
# 2          3    15619304      Onio        502.0    France     NaN  44.768141
# 3          4    15701354      Boni        699.0    France     NaN  39.000000
# 4          5    15737888  Mitchell        850.0     Spain  Female  43.000000
# 5          6    15574012       Chu        645.0     Spain    Male  44.000000
# 6          7    15592531  Bartlett        822.0    France    Male  50.000000
# 7          8    15656148    Obinna        376.0   Germany  Female  29.000000
# 8          9    15792365        He        501.0    France    Male  44.000000
# 9         10    15592389        H?          NaN    France    Male  27.000000
#
#    Tenure        Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.000000              1          1               1
# 1       1   83807.860000              1          0               1
# 2       8  159660.800000              3          1               0
# 3       1       0.000000              2          0               0
# 4       2   72593.003473              1          1               1
# 5       8  113755.780000              2          1               0
# 6       7       0.000000              2          1               1
# 7       4  115046.740000              4          1               0
# 8       4  142051.070000              2          0               1
# 9       2  134603.880000              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88     1.0
# 1        112542.58     0.0
# 2        113931.57     1.0
# 3         93826.63     0.0
# 4         79084.10     0.0
# 5              NaN     1.0
# 6         10062.80     0.0
# 7        119346.88     1.0
# 8         74940.50     0.0
# 9         71725.73     0.0

# %%
# !pip install scipy
# !pip install miceforest --no-cache-dir
# Out:
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\user\anaconda3\lib\site-packages (from scipy) (1.19.2)
# Requirement already satisfied: miceforest in c:\users\user\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: lightgbm>=3.3.1 in c:\users\user\anaconda3\lib\site-packages (from miceforest) (4.3.0)
# Requirement already satisfied: dill in c:\users\user\anaconda3\lib\site-packages (from miceforest) (0.3.8)
# Requirement already satisfied: blosc in c:\users\user\anaconda3\lib\site-packages (from miceforest) (1.11.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from miceforest) (1.19.2)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from lightgbm>=3.3.1->miceforest) (1.5.2)

# %%
import miceforest as mf

# %%
# Create kernel.
kds = mf.ImputationKernel(
  df_train,
  save_all_iterations=True,
  random_state=100
)

# Run the MICE algorithm for 2 iterations
kds.mice(2)

# Return the completed dataset.
df_imputed = kds.complete_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b9349cad55cd> in <module>
#       7
#       8 # Run the MICE algorithm for 2 iterations
# ----> 9 kds.mice(2)
#      10
#      11 # Return the completed dataset.
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\ImputationKernel.py in mice(self, iterations, verbose, variable_parameters, compile_candidates, **kwlgb)
#    1181
#    1182                         logger.set_start_time()
# -> 1183                         imp_values = self.mean_match_scheme._mean_match(
#    1184                             variable, objective, **mm_kwargs
#    1185                         )
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\MeanMatchScheme.py in _mean_match(self, variable, objective, **kwargs)
#     392
#     393         mmf_args = {arg: val for arg, val in kwargs.items() if arg in obj_args}
# --> 394         imp_values = mmf(**mmf_args)
#     395         return imp_values
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\builtin_mean_match_functions.py in _mean_match_reg(mean_match_candidates, bachelor_preds, candidate_preds, candidate_values, random_state, hashed_seeds)
#      37         # balanced_tree = False fixes a recursion issue for some reason.
#      38         # https://github.com/scipy/scipy/issues/14799
# ---> 39         kd_tree = KDTree(candidate_preds, leafsize=16, balanced_tree=False)
#      40         _, knn_indices = kd_tree.query(
#      41             bachelor_preds, k=mean_match_candidates, workers=-1
#
# TypeError: __init__() got an unexpected keyword argument 'balanced_tree'

# %%
df_train.head()
# Out:
#      Balance   Age  Exited
# 0       0.00  42.0       1
# 1   83807.86  41.0       0
# 2  159660.80   NaN       1
# 3       0.00  39.0       0
# 4        NaN  43.0       0

# %%
df_imputed.head()

# It has predicted a value of '55' for the missing record.

# Let's run for 5 more iterations and predict again.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f6be9e9301b9> in <module>
# ----> 1 df_imputed.head()
#       2
#       3 # It has predicted a value of '55' for the missing record.
#       4
#       5 # Let's run for 5 more iterations and predict again.
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
kds.mice(iterations=5, n_estimators=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5f8d5cbb1b37> in <module>
# ----> 1 kds.mice(iterations=5, n_estimators=50)
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\ImputationKernel.py in mice(self, iterations, verbose, variable_parameters, compile_candidates, **kwlgb)
#    1181
#    1182                         logger.set_start_time()
# -> 1183                         imp_values = self.mean_match_scheme._mean_match(
#    1184                             variable, objective, **mm_kwargs
#    1185                         )
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\MeanMatchScheme.py in _mean_match(self, variable, objective, **kwargs)
#     392
#     393         mmf_args = {arg: val for arg, val in kwargs.items() if arg in obj_args}
# --> 394         imp_values = mmf(**mmf_args)
#     395         return imp_values
#
# c:\Users\User\anaconda3\lib\site-packages\miceforest\builtin_mean_match_functions.py in _mean_match_reg(mean_match_candidates, bachelor_preds, candidate_preds, candidate_values, random_state, hashed_seeds)
#      37         # balanced_tree = False fixes a recursion issue for some reason.
#      38         # https://github.com/scipy/scipy/issues/14799
# ---> 39         kd_tree = KDTree(candidate_preds, leafsize=16, balanced_tree=False)
#      40         _, knn_indices = kd_tree.query(
#      41             bachelor_preds, k=mean_match_candidates, workers=-1
#
# TypeError: __init__() got an unexpected keyword argument 'balanced_tree'

# %%
df_imputed2 = kds.complete_data()
df_imputed2.head()
# Out:
#      Balance   Age  Exited
# 0       0.00  42.0       1
# 1   83807.86  41.0       0
# 2  159660.80  29.0       1
# 3       0.00  39.0       0
# 4  160474.59  43.0       0

# %%
# The prediction has now changed from 55 to 39.

# %%
# Let's compare the actual value by loading the original data that does not contain the missing values

import pandas as pd
file_path = "https://raw.githubusercontent.com/armandoordonez/eda_couse/main/data/Churn_Modelling_orig.csv"
dfs = pd.read_csv(file_path)
dfs[['Balance', 'Age', 'Exited']].head()
# Out:
#      Balance  Age  Exited
# 0       0.00   42       1
# 1   83807.86   41       0
# 2  159660.80   42       1
# 3       0.00   39       0
# 4  125510.82   43       0
